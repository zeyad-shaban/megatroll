# %%
import numpy as np
from ultralytics import YOLO
import cv2
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# model = YOLO("C:/Users/zeyad/Master/1_Projects/1_Active/MegaTroll/ai_training/bottle_ds_training/runs/detect/train-9/weights/best.pt")

# cap = cv2.VideoCapture("http://192.168.43.1:8080/video")
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    if not ret:
        print("No results")
        break
    
    results = model.track(
        frame,
        persist=True,
        tracker="./tracker_conf.yaml",
    )
    
    annotated_frame = results[0].plot()
    cv2.imshow("Detection", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cv2.destroyAllWindows()
# Out:
# 0: 288x320 1 BottleDetection, 32.1ms
# Speed: 0.8ms preprocess, 32.1ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 31.1ms
# Speed: 0.8ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 35.6ms
# Speed: 0.8ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 36.4ms
# Speed: 0.8ms preprocess, 36.4ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 38.2ms
# Speed: 0.8ms preprocess, 38.2ms inference, 0.4ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 37.8ms
# Speed: 1.0ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 288x320 1 BottleDetection, 30.6ms
# Speed: 0.7ms preprocess, 30.6ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 320)
